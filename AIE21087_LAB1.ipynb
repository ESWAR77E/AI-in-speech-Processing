# %% [markdown]
# ## N eswar
# ## BL.EN.U4AIE21087

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd

custom_y, custom_sr = librosa.load('Recording.wav')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(y, color='red')  
plt.title('Speech Signal Waveform')
plt.show()

# %%
print("Length of the custom signal:", len(custom_y), "samples")
print("Custom sampling rate:", custom_sr, "Hz")
print("Custom magnitude range:", np.min(custom_y), "to", np.max(custom_y))
# Out:
# Length of the custom signal: 82791 samples
# Custom sampling rate: 22050 Hz
# Custom magnitude range: -0.17756784 to 0.16614652

# %%
custom_start = int(3 * custom_sr)
custom_end = int(7 * custom_sr)
custom_segment = custom_y[custom_start:custom_end]
librosa.display.waveshow(custom_segment, color='red')  
ipd.Audio(custom_segment, rate=custom_sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
custom_segment_1_start = int(1 * custom_sr)
custom_segment_1_end = int(4 * custom_sr)
custom_segment_2_start = int(2 * custom_sr)
custom_segment_2_end = int(3 * custom_sr)
custom_segment_1 = custom_y[custom_segment_1_start:custom_segment_1_end]
custom_segment_2 = custom_y[custom_segment_2_start:custom_segment_2_end]
print("Playing Custom Segment 1:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(custom_segment_1, color='red')  # Changing the plot color to blue
plt.title('Custom Segment-1')
plt.show()
ipd.Audio(custom_segment_1, rate=custom_sr)
# Out:
# Playing Custom Segment 1:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing Custom Segment 2:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(custom_segment_2, color='red')  # Changing the plot color to red
plt.title('Custom Segment-2')
plt.show()
ipd.Audio(custom_segment_2, rate=custom_sr)
# Out:
# Playing Custom Segment 2:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
